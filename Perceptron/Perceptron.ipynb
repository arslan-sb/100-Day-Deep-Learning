# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x=df['cgpa'],y=df['resume_score'],hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
from sklearn.model_selection import train_test_split

# %%
# x_train,x_test, y_train, y_test= train_test_split(df)
x= df.iloc[:,:2]
y= df.iloc[:,-1]
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: placed, dtype: int64

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron(tol=1e-3, random_state=10)

# %%
p.fit(x,y)
# Out:
# Perceptron(random_state=10)

# %%
p.coef_
# Out:
# array([[ 39.72, -34.37]])

# %%
p.intercept_
# Out:
# array([-27.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values,y.values,clf=p,legend=2)
# Out:
# /home/arslan/miniconda3/envs/tf/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
